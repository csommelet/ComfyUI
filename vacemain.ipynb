# %%
import sys
print(sys.argv)
sys.argv = sys.argv[:1] + ["--disable-xformers"]
import main
# Out:
# ['/workspace/ComfyUI/venv/lib/python3.12/site-packages/ipykernel_launcher.py', '--f=/root/.local/share/jupyter/runtime/kernel-v349ca41f8b10f4f2e3fec3d04efd75088287b3d1c.json']
# Main1
# Main2
# Main2.1
# Main2.2
# Main3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(sys.argv)
#       3 sys.argv = sys.argv[:1] + ["--disable-xformers"]
# ----> 4 import main
#
# File /workspace/ComfyUI/main.py:28
#      25     os.environ['HF_HUB_DISABLE_TELEMETRY'] = '1'
#      26     os.environ['DO_NOT_TRACK'] = '1'
# ---> 28 setup_logger(log_level=args.verbose, use_stdout=args.log_stdout)
#      30 def apply_custom_paths():
#      31     # extra model paths
#      32     extra_model_paths_config_path = os.path.join(os.path.dirname(os.path.realpath(__file__)), "extra_model_paths.yaml")
#
# ...
